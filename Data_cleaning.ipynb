# %%
# import libraries

import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %%
# immport dataset

ds= pd.read_csv("Dataset_Flight.csv")
ds
# Out:
#            Airline Date_of_Journey    Source Destination Duration Total_Stops  \
# 0           IndiGo      24/03/2019  Banglore   New Delhi   2h 50m    non-stop
# 1        Air India       1/05/2019   Kolkata    Banglore   7h 25m     2 stops
# 2      Jet Airways       9/06/2019     Delhi      Cochin      19h     2 stops
# 3           IndiGo      12/05/2019   Kolkata    Banglore   5h 25m      1 stop
# 4           IndiGo      01/03/2019  Banglore   New Delhi   4h 45m      1 stop
# ...            ...             ...       ...         ...      ...         ...
# 10678     Air Asia       9/04/2019   Kolkata    Banglore   2h 30m    non-stop
# 10679    Air India      27/04/2019   Kolkata    Banglore   2h 35m    non-stop
# 10680  Jet Airways      27/04/2019  Banglore       Delhi       3h    non-stop
# 10681      Vistara      01/03/2019  Banglore   New Delhi   2h 40m    non-stop
# 10682    Air India       9/05/2019     Delhi      Cochin   8h 20m     2 stops
#
#       Additional_Info  Price
# ...

# %%
ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10683 entries, 0 to 10682
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          10683 non-null  object
#  1   Date_of_Journey  10683 non-null  object
#  2   Source           10683 non-null  object
#  3   Destination      10683 non-null  object
#  4   Duration         10683 non-null  object
#  5   Total_Stops      10682 non-null  object
#  6   Additional_Info  10683 non-null  object
#  7   Price            10683 non-null  int64
# dtypes: int64(1), object(7)
# memory usage: 667.8+ KB

# %%
ds.describe()
# Out:
#               Price
# count  10683.000000
# mean    9087.064121
# std     4611.359167
# min     1759.000000
# 25%     5277.000000
# 50%     8372.000000
# 75%    12373.000000
# max    79512.000000

# %%
# searching duplicated
ds.duplicated().sum()
# Out:
# 1013

# %%
# removing duplicates
ds.drop_duplicates(inplace=True)

# %%
# checking null value

ds.isnull().sum()
# Out:
# Airline            0
# Date_of_Journey    0
# Source             0
# Destination        0
# Duration           0
# Total_Stops        1
# Additional_Info    0
# Price              0
# dtype: int64

# %%
# drop emplty cells
ds.dropna(inplace=True)

# %%
ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9669 entries, 0 to 10682
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          9669 non-null   object
#  1   Date_of_Journey  9669 non-null   object
#  2   Source           9669 non-null   object
#  3   Destination      9669 non-null   object
#  4   Duration         9669 non-null   object
#  5   Total_Stops      9669 non-null   object
#  6   Additional_Info  9669 non-null   object
#  7   Price            9669 non-null   int64
# dtypes: int64(1), object(7)
# memory usage: 679.9+ KB

# %%
ds.columns
# Out:
# Index(['Airline', 'Date_of_Journey', 'Source', 'Destination', 'Duration',
#        'Total_Stops', 'Additional_Info', 'Price'],
#       dtype='object')

# %%
# finding for unique values in year
ds["Airline"].unique()
# Out:
# array(['IndiGo', 'Air India', 'Jet Airways', 'SpiceJet',
#        'Multiple carriers', 'GoAir', 'Vistara', 'Air Asia',
#        'Vistara Premium economy', 'Jet Airways Business',
#        'Multiple carriers Premium economy', 'Trujet'], dtype=object)

# %%
# handling date

ds["Date_of_Journey"] =pd.to_datetime(ds["Date_of_Journey"])
ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9669 entries, 0 to 10682
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          9669 non-null   object
#  1   Date_of_Journey  9669 non-null   datetime64[ns]
#  2   Source           9669 non-null   object
#  3   Destination      9669 non-null   object
#  4   Duration         9669 non-null   object
#  5   Total_Stops      9669 non-null   object
#  6   Additional_Info  9669 non-null   object
#  7   Price            9669 non-null   int64
# dtypes: datetime64[ns](1), int64(1), object(6)
# memory usage: 679.9+ KB

# %%
print(ds.to_string())
# Out:
#                                  Airline Date_of_Journey    Source Destination Duration Total_Stops               Additional_Info  Price
# 0                                 IndiGo      2019-03-24  Banglore   New Delhi   2h 50m    non-stop                       No info   3897
# 1                              Air India      2019-05-01   Kolkata    Banglore   7h 25m     2 stops                       No info   7662
# 2                            Jet Airways      2019-06-09     Delhi      Cochin      19h     2 stops                       No info  13882
# 3                                 IndiGo      2019-05-12   Kolkata    Banglore   5h 25m      1 stop                       No info   6218
# 4                                 IndiGo      2019-03-01  Banglore   New Delhi   4h 45m      1 stop                       No info  13302
# 5                               SpiceJet      2019-06-24   Kolkata    Banglore   2h 25m    non-stop                       No info   3873
# ...

# %%
def duration_to_mins(x):
    h, m = 0, 0
    if 'h' in x:
        h = int(x.split('h')[0].strip())
        x = x.split('h')[1].strip()
    if 'm' in x:
        m = int(x.split('m')[0].strip())
    return h*60 + m

ds['Duration'] = ds['Duration'].apply(duration_to_mins)
ds
# Out:
#            Airline Date_of_Journey    Source Destination  Duration  \
# 0           IndiGo      2019-03-24  Banglore   New Delhi       170
# 1        Air India      2019-05-01   Kolkata    Banglore       445
# 2      Jet Airways      2019-06-09     Delhi      Cochin      1140
# 3           IndiGo      2019-05-12   Kolkata    Banglore       325
# 4           IndiGo      2019-03-01  Banglore   New Delhi       285
# ...            ...             ...       ...         ...       ...
# 10677     SpiceJet      2019-05-21  Banglore       Delhi       160
# 10678     Air Asia      2019-04-09   Kolkata    Banglore       150
# 10679    Air India      2019-04-27   Kolkata    Banglore       155
# 10681      Vistara      2019-03-01  Banglore   New Delhi       160
# 10682    Air India      2019-05-09     Delhi      Cochin       500
#
#       Total_Stops               Additional_Info  Price
# 0        non-stop                       No info   3897
# ...

# %%
# handling Total_Stops
ds['Total_Stops']=ds["Total_Stops"].str.replace("non-stop","0").str.replace(" stops","").str.replace(" stop","")

# %%
# convert into numeric datatype
ds["Total_Stops"] =pd.to_numeric(ds["Total_Stops"],errors= 'coerce')

# %%
ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9669 entries, 0 to 10682
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          9669 non-null   object
#  1   Date_of_Journey  9669 non-null   datetime64[ns]
#  2   Source           9669 non-null   object
#  3   Destination      9669 non-null   object
#  4   Duration         9669 non-null   int64
#  5   Total_Stops      9669 non-null   int64
#  6   Additional_Info  9669 non-null   object
#  7   Price            9669 non-null   int64
# dtypes: datetime64[ns](1), int64(3), object(4)
# memory usage: 679.9+ KB

# %%
ds
# Out:
#            Airline Date_of_Journey    Source Destination  Duration  \
# 0           IndiGo      2019-03-24  Banglore   New Delhi       170
# 1        Air India      2019-05-01   Kolkata    Banglore       445
# 2      Jet Airways      2019-06-09     Delhi      Cochin      1140
# 3           IndiGo      2019-05-12   Kolkata    Banglore       325
# 4           IndiGo      2019-03-01  Banglore   New Delhi       285
# ...            ...             ...       ...         ...       ...
# 10677     SpiceJet      2019-05-21  Banglore       Delhi       160
# 10678     Air Asia      2019-04-09   Kolkata    Banglore       150
# 10679    Air India      2019-04-27   Kolkata    Banglore       155
# 10681      Vistara      2019-03-01  Banglore   New Delhi       160
# 10682    Air India      2019-05-09     Delhi      Cochin       500
#
#        Total_Stops               Additional_Info  Price
# 0                0                       No info   3897
# ...

# %%
ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9669 entries, 0 to 10682
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          9669 non-null   object
#  1   Date_of_Journey  9669 non-null   datetime64[ns]
#  2   Source           9669 non-null   object
#  3   Destination      9669 non-null   object
#  4   Duration         9669 non-null   int64
#  5   Total_Stops      9669 non-null   int64
#  6   Additional_Info  9669 non-null   object
#  7   Price            9669 non-null   int64
# dtypes: datetime64[ns](1), int64(3), object(4)
# memory usage: 679.9+ KB

# %%
ds.to_csv("New_clean_data.csv",index=False)
