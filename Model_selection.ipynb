# %%
# import libraries

import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %%
# import datset 
ds=pd.read_csv("New_clean_data.csv", parse_dates=['Date_of_Journey'])
ds
# Out:
#           Airline Date_of_Journey    Source Destination  Duration  \
# 0          IndiGo      2019-03-24  Banglore   New Delhi       170
# 1       Air India      2019-05-01   Kolkata    Banglore       445
# 2     Jet Airways      2019-06-09     Delhi      Cochin      1140
# 3          IndiGo      2019-05-12   Kolkata    Banglore       325
# 4          IndiGo      2019-03-01  Banglore   New Delhi       285
# ...           ...             ...       ...         ...       ...
# 9664     SpiceJet      2019-05-21  Banglore       Delhi       160
# 9665     Air Asia      2019-04-09   Kolkata    Banglore       150
# 9666    Air India      2019-04-27   Kolkata    Banglore       155
# 9667      Vistara      2019-03-01  Banglore   New Delhi       160
# 9668    Air India      2019-05-09     Delhi      Cochin       500
#
#       Total_Stops               Additional_Info  Price
# 0               0                       No info   3897
# 1               2                       No info   7662
# ...

# %%
ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9669 entries, 0 to 9668
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          9669 non-null   object
#  1   Date_of_Journey  9669 non-null   datetime64[ns]
#  2   Source           9669 non-null   object
#  3   Destination      9669 non-null   object
#  4   Duration         9669 non-null   int64
#  5   Total_Stops      9669 non-null   int64
#  6   Additional_Info  9669 non-null   object
#  7   Price            9669 non-null   int64
# dtypes: datetime64[ns](1), int64(3), object(4)
# memory usage: 604.4+ KB

# %%
# removing unnamed column
ds = ds.loc[:, ~ds.columns.str.contains('^Unnamed')]             
ds
# Out:
#           Airline Date_of_Journey    Source Destination  Duration  \
# 0          IndiGo      2019-03-24  Banglore   New Delhi       170
# 1       Air India      2019-05-01   Kolkata    Banglore       445
# 2     Jet Airways      2019-06-09     Delhi      Cochin      1140
# 3          IndiGo      2019-05-12   Kolkata    Banglore       325
# 4          IndiGo      2019-03-01  Banglore   New Delhi       285
# ...           ...             ...       ...         ...       ...
# 9664     SpiceJet      2019-05-21  Banglore       Delhi       160
# 9665     Air Asia      2019-04-09   Kolkata    Banglore       150
# 9666    Air India      2019-04-27   Kolkata    Banglore       155
# 9667      Vistara      2019-03-01  Banglore   New Delhi       160
# 9668    Air India      2019-05-09     Delhi      Cochin       500
#
#       Total_Stops               Additional_Info  Price
# 0               0                       No info   3897
# 1               2                       No info   7662
# ...

# %%
ds.columns
# Out:
# Index(['Airline', 'Date_of_Journey', 'Source', 'Destination', 'Duration',
#        'Total_Stops', 'Additional_Info', 'Price'],
#       dtype='object')

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
ds['Duration'] = scaler.fit_transform(ds[['Duration']])
ds
# Out:
#           Airline Date_of_Journey    Source Destination  Duration  \
# 0          IndiGo      2019-03-24  Banglore   New Delhi -0.983966
# 1       Air India      2019-05-01   Kolkata    Banglore -0.436499
# 2     Jet Airways      2019-06-09     Delhi      Cochin  0.947101
# 3          IndiGo      2019-05-12   Kolkata    Banglore -0.675394
# 4          IndiGo      2019-03-01  Banglore   New Delhi -0.755025
# ...           ...             ...       ...         ...       ...
# 9664     SpiceJet      2019-05-21  Banglore       Delhi -1.003874
# 9665     Air Asia      2019-04-09   Kolkata    Banglore -1.023782
# 9666    Air India      2019-04-27   Kolkata    Banglore -1.013828
# 9667      Vistara      2019-03-01  Banglore   New Delhi -1.003874
# 9668    Air India      2019-05-09     Delhi      Cochin -0.327005
#
#       Total_Stops               Additional_Info  Price
# 0               0                       No info   3897
# 1               2                       No info   7662
# ...

# %%
# spliting dataset into independent and dependent variable

x =ds[['Airline', 'Date_of_Journey', 'Source', 'Destination', 'Duration',
       'Total_Stops']]
y= ds[["Price"]]

# %%
# Encoding

from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import make_column_transformer
ohe =OneHotEncoder()
ohe.fit(x[['Airline', 'Date_of_Journey', 'Source', 'Destination', 'Duration',
       'Total_Stops']])
# Out:
# OneHotEncoder()

# %%
# column transformer
ct =make_column_transformer((OneHotEncoder(handle_unknown ='ignore',categories=ohe.categories_),['Airline', 'Date_of_Journey', 'Source', 'Destination', 'Duration',
       'Total_Stops']),remainder= 'passthrough',force_int_remainder_cols=False,sparse_threshold=0)
ct
# Out:
# ColumnTransformer(force_int_remainder_cols=False, remainder='passthrough',
#                   sparse_threshold=0,
#                   transformers=[('onehotencoder',
#                                  OneHotEncoder(categories=[array(['Air Asia', 'Air India', 'GoAir', 'IndiGo', 'Jet Airways',
#        'Jet Airways Business', 'Multiple carriers',
#        'Multiple carriers Premium economy', 'SpiceJet', 'Trujet',
#        'Vistara', 'Vistara Premium economy'], dtype=object),
#                                                            a...
#         2.99761479e+00,  3.02747664e+00,  3.11706221e+00,  3.13697012e+00,
#         3.14692407e+00,  3.21660173e+00,  3.24646359e+00,  3.25641754e+00,
#         3.28627940e+00,  3.34600311e+00,  3.49531239e+00,  3.61475981e+00,
#         3.70434538e+00,  3.78397700e+00,  4.29162855e+00,  4.37126017e+00]),
#                                                            array([0, 1, 2, 3, 4], dtype=int64)],
# ...

# %%
# making pipeline

from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor 
from sklearn.ensemble import RandomForestRegressor
from sklearn.pipeline import make_pipeline
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score,mean_squared_error

regMLR=LinearRegression()
regDTR= DecisionTreeRegressor(random_state=0)
regRFR =RandomForestRegressor(n_estimators= 10,random_state=0)

pipeLinear = make_pipeline(ct, regMLR)
pipeDec = make_pipeline(ct, regDTR)
pipeRFR = make_pipeline(ct, regRFR)

scores=[]
for i in range(0,101):
    x_train,x_test,y_train,y_test= train_test_split(x,y,test_size=0.10,random_state=i)
    pipeLinear.fit(x_train,y_train)
    pipeDec.fit(x_train,y_train)
    pipeRFR.fit(x_train,y_train)
    
    result =pipeLinear.predict(x_test)
    scoreLinear =r2_score(y_test,result)
    rmseLinear = np.sqrt(mean_squared_error(y_test, result))
     
    result = pipeDec.predict(x_test)
    scoreDec = r2_score(y_test, result)
    rmseDec = np.sqrt(mean_squared_error(y_test, result))
    
    result = pipeRFR.predict(x_test)
    scoreRFR = r2_score(y_test, result)
    rmseRFR = np.sqrt(mean_squared_error(y_test, result))
    
    scores.append(('Linear',i, scoreLinear,rmseLinear))
    scores.append(('Decision',i, scoreDec, rmseDec ))
    scores.append(('Random Forest',i, scoreRFR, rmseRFR ))

# %%
#Finding best r2 score and RMSE score

scoreDF = pd.DataFrame(data = scores, columns = ["algo", "Iteration", "R2 score", "RMSE Score"])
resultDF = scoreDF.sort_values(by="R2 score", ascending = False)
resultDF
# r2 score must be maximum and RMSE score must be minimum
# Out:
#               algo  Iteration      R2 score    RMSE Score
# 50   Random Forest         16  8.198837e-01  2.030918e+03
# 115       Decision         38  8.073083e-01  2.241495e+03
# 116  Random Forest         38  8.021248e-01  2.271444e+03
# 293  Random Forest         97  7.970191e-01  2.201175e+03
# 134  Random Forest         44  7.938824e-01  2.383142e+03
# ..             ...        ...           ...           ...
# 186         Linear         62 -5.245587e+22  9.665072e+14
# 21          Linear          7 -5.384982e+22  1.079303e+15
# 285         Linear         95 -6.359959e+22  1.180190e+15
# 12          Linear          4 -1.246656e+23  1.495220e+15
# 246         Linear         82 -4.489107e+23  3.152066e+15
#
# [303 rows x 4 columns]

# %%
 # Making Pipeline for best suited algorithm(Decision tree) 

x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.10,random_state=79)
pipeDec.fit(x_train,y_train)
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(force_int_remainder_cols=False,
#                                    remainder='passthrough', sparse_threshold=0,
#                                    transformers=[('onehotencoder',
#                                                   OneHotEncoder(categories=[array(['Air Asia', 'Air India', 'GoAir', 'IndiGo', 'Jet Airways',
#        'Jet Airways Business', 'Multiple carriers',
#        'Multiple carriers Premium economy', 'SpiceJet', 'Trujet',
#        'Vistara', 'Vi...
#         3.14692407e+00,  3.21660173e+00,  3.24646359e+00,  3.25641754e+00,
#         3.28627940e+00,  3.34600311e+00,  3.49531239e+00,  3.61475981e+00,
#         3.70434538e+00,  3.78397700e+00,  4.29162855e+00,  4.37126017e+00]),
#                                                                             array([0, 1, 2, 3, 4], dtype=int64)],
#                                                                 handle_unknown='ignore'),
# ...

# %%
airline = input("Enter Airline (e.g., IndiGo, Air India, etc.): ")
date_of_Journey = input("Enter Date of Journey (DD/MM/YYYY): ")
source = input("Enter Source city (e.g., Delhi, Kolkata): ")
destination= input("Enter Destination city (e.g., Cochin, Delhi): ")
duration= input("Enter Duration (e.g., '2h 50m', '50m', '2h'): ")
total_Stops= input("Enter Total Stops (e.g., 'non-stop', '1 stop', '2 stops'): ")

columns =['Airline', 'Date_of_Journey', 'Source', 'Destination', 'Duration','Total_Stops']

myinput = pd.DataFrame(columns=columns,data =[[airline ,date_of_Journey,source,destination,duration,total_Stops]])
result =pipeDec.predict(myinput)
print("You should buy it for ~price :",round(result[0]))
# Out:
# Enter Airline (e.g., IndiGo, Air India, etc.):  IndiGo
# Enter Date of Journey (DD/MM/YYYY):  20-7-2025
# Enter Source city (e.g., Delhi, Kolkata):  Delhi
# Enter Destination city (e.g., Cochin, Delhi):  Cochin
# Enter Duration (e.g., '2h 50m', '50m', '2h'):  2h 50m
# Enter Total Stops (e.g., 'non-stop', '1 stop', '2 stops'):  non-stop
# You should buy it for ~price : 6494

# %%
import pickle as pkl

# %%
pkl.dump(pipeDec,open("PlaneTicketPricePredcition.pkl","wb"))
